# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.datasets import mnist

# %%
(x_train, y_train),(x_test,y_test)=mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
x_test=x_test/255.0
x_train=x_train/255.0

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(10,activation='softmax')
])

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics='accuracy')

# %%
model.fit(x_train,y_train,epochs=6)
# Out:
# Epoch 1/6
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.2568 - accuracy: 0.9277
# Epoch 2/6
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.1095 - accuracy: 0.9678
# Epoch 3/6
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0757 - accuracy: 0.9768
# Epoch 4/6
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0572 - accuracy: 0.9821
# Epoch 5/6
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0434 - accuracy: 0.9868
# Epoch 6/6
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0352 - accuracy: 0.9887

# %%
loss,acc=model.evaluate(x_test,y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0748 - accuracy: 0.9777

# %%
p=model.predict(x_test[:5])
# Out:
# 1/1 [==============================] - 0s 85ms/step

# %%
p
# Out:
# array([[1.4197276e-07, 3.5752456e-07, 1.7065369e-05, 1.3499948e-02,
#         2.4534388e-11, 1.6166006e-06, 2.1030934e-11, 9.8645031e-01,
#         8.0570624e-07, 2.9782805e-05],
#        [7.1752365e-12, 2.8361140e-07, 9.9999976e-01, 1.4502245e-09,
#         5.1854319e-18, 8.7864144e-10, 4.9768197e-12, 3.5145870e-14,
#         5.8487509e-10, 1.4960908e-13],
#        [4.3566644e-08, 9.9970311e-01, 1.7099037e-05, 4.0053055e-07,
#         4.3024254e-05, 7.6103373e-07, 2.5660529e-06, 1.9229484e-04,
#         3.8082060e-05, 2.6319556e-06],
#        [9.9979597e-01, 1.3414562e-09, 1.7383369e-04, 2.1451104e-08,
#         1.8666871e-10, 1.8665752e-08, 3.2900039e-07, 2.9775651e-05,
#         7.2538042e-10, 6.6573485e-08],
#        [6.6043071e-07, 2.8195306e-09, 2.4830788e-05, 2.7502478e-09,
#         9.9907696e-01, 1.9456191e-08, 4.3585743e-07, 1.5672864e-05,
#         4.1958955e-07, 8.8086451e-04]], dtype=float32)

# %%
for i in range(5):
    plt.imshow(x_test[i], cmap=plt.cm.binary)
    plt.title(f"Predicted label: {np.argmax(p[i])}")
    plt.show()
